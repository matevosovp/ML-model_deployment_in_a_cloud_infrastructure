# %%
import pandas as pd

# %%
import sys, subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install", "boto3"])
# Out:
# Collecting boto3
#   Downloading boto3-1.42.17-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 1.0 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.43.0,>=1.42.17
#   Downloading botocore-1.42.17-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 45.0 MB/s eta 0:00:00
# Collecting s3transfer<0.17.0,>=0.16.0
#   Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 6.6 MB/s eta 0:00:00
# Collecting urllib3!=2.2.0,<3,>=1.25.4
#   Using cached urllib3-2.6.2-py3-none-any.whl (131 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./.venv_project_name/lib/python3.10/site-packages (from botocore<1.43.0,>=1.42.17->boto3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv_project_name/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.17->boto3) (1.17.0)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.42.17 botocore-1.42.17 jmespath-1.0.1 s3transfer-0.16.0 urllib3-2.6.2
# 0

# %%
import os
import boto3
from botocore.client import Config

bucket = os.environ["S3_BUCKET_NAME"]
endpoint = os.getenv("MLFLOW_S3_ENDPOINT_URL", "https://storage.yandexcloud.net")
key = "models/Sprint2_cb.pkl"

s3 = boto3.client(
    "s3",
    endpoint_url=endpoint,
    aws_access_key_id=os.environ["AWS_ACCESS_KEY_ID"],
    aws_secret_access_key=os.environ["AWS_SECRET_ACCESS_KEY"],
    config=Config(signature_version="s3v4"),
)

s3.download_file(bucket, key, "Sprint2_cb.pkl")
print("Downloaded Sprint2_cb.pkl")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 5
#       2 import boto3
#       3 from botocore.client import Config
# ----> 5 bucket = os.environ["S3_BUCKET_NAME"]
#       6 endpoint = os.getenv("MLFLOW_S3_ENDPOINT_URL", "https://storage.yandexcloud.net")
#       7 key = "models/Sprint2_cb.pkl"
#
# File /usr/lib/python3.10/os.py:680, in _Environ.__getitem__(self, key)
#     677     value = self._data[self.encodekey(key)]
#     678 except KeyError:
#     679     # raise KeyError with the original key value
# --> 680     raise KeyError(key) from None
#     681 return self.decodevalue(value)
#
# KeyError: 'S3_BUCKET_NAME'
